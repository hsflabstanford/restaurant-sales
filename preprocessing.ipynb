# %%
import tqdm
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import sklearn as sk
import statsmodels as sm
import os

# %%
print(os.getcwd())
print(os.listdir())

# %%
#customers_1 = pd.read_excel("palate_data/batch_1/customers.xlsx")
before_after_details_1 = pd.read_excel("palate_data/batch_1/before_after_details.xlsx")
locations_1 = pd.read_excel("palate_data/batch_1/locations.xlsx")
items_tagged_1 = pd.read_excel("palate_data/batch_1/items_tagged.xlsx")
items_tagged_v2_1 = pd.read_excel("palate_data/batch_1/items_tagged_v2.xlsx")

# %%
customers1.shape
