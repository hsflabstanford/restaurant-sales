# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import scipy as sp
import statsmodels as sm
import sklearn as sk
import os
import re
import time
from tqdm import tqdm
from filters import FilterDF

# %%
# %store -r static_reference_data
# %store -r restaurant_sales_data

# %% [markdown]
# ## Static reference data exploration

# %%
before_after_details = static_reference_data[0].copy()
customers = static_reference_data[1].copy()
items_tagged = static_reference_data[2].copy()
locations = static_reference_data[3].copy()

# %% [markdown]
# ### Menu Stats

# %%
items_tagged_noalc = items_tagged[items_tagged['dish_category'] != 'Alcohol'].copy()
plant_based = items_tagged_noalc.loc[items_tagged_noalc['is_plant_based'] == 'yes',:].copy()

# %%
items_tagged.columns

# %%
items_tagged['item_type'].value_counts()

# %%
items_tagged['dish_category'].value_counts()

# %%
items_tagged['ingredients'].value_counts()

# %%
items_tagged['brand'].value_counts()

# %% [markdown]
# ### Menu Visuals

# %%
plt.bar(items_tagged['is_plant_based'].value_counts().index, items_tagged['is_plant_based'].value_counts())
plt.title("Total Menu Items: Is it Plant-Based?")
plt.show()

# %%
plt.bar(items_tagged['item_type'].value_counts().index, items_tagged['item_type'].value_counts())
plt.title("Total Menu Items: Item Types")
plt.show()

# %%
plt.bar(items_tagged['dish_category'].value_counts()[:20].index, items_tagged['dish_category'].value_counts()[:20])
plt.title("Total Menu Items: Dish Categories")
plt.xticks(rotation = 75)
plt.show()

# %%
plt.bar(items_tagged_noalc['is_plant_based'].value_counts().index, items_tagged_noalc['is_plant_based'].value_counts(), color="red")
plt.title("Menu Items without Alcohol: Is it Plant-Based?")
plt.show()

# %%
plt.bar(items_tagged_noalc['item_type'].value_counts().index, items_tagged_noalc['item_type'].value_counts(), color="red")
plt.title("Menu Items without Alcohol: Item Types")
plt.show()

# %%
plt.bar(items_tagged_noalc['dish_category'].value_counts()[:20].index, items_tagged_noalc['dish_category'].value_counts()[:20], color="red")
plt.title("Menu Items without Alcohol: Dish Categories")
plt.xticks(rotation = 75)
plt.show()

# %%
plt.bar(plant_based['item_type'].value_counts().index, plant_based['item_type'].value_counts(), color="green")
plt.title("Plant-Based Menu Items without Alcohol: Item Types")
plt.show()

# %%
plt.bar(plant_based['dish_category'].value_counts()[:20].index, plant_based['dish_category'].value_counts()[:20], color="green")
plt.title("Plant-Based Menu Items without Alcohol: Dish Categories")
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# ## Time Series Exploration

# %%
location_ids = list(restaurant_sales_data.keys())

# %% [markdown]
# ### General Info

# %% [markdown]
# Timeframes

# %%
list_of_timeframes = []
for location_id, df in tqdm(restaurant_sales_data.items()):
    timedelta = df.index[-1] - df.index[0]
    years = timedelta.days / 365.25
    list_of_timeframes.append(years)
timeframes = np.array(list_of_timeframes)
print("Median: {:.2f} year range".format(np.median(timeframes)))
print("Mean: {:.2f} year range".format(np.mean(timeframes)))
print("SD: {:.2f} years".format(np.std(timeframes)))
print("Restaurants with less than a 2 year range: {}".format((timeframes < 2).sum()))

# %%
from filters import FilterDF

# %%
fdf1 = FilterDF(restaurant_sales_data[location_id])
fdf1.multi_filter([('item_quantity', 2), ('item_name', ['Pretzel', 'Bootjack IPA'])])

# %% [markdown]
# ### Data Integrity Checks

# %% [markdown]
# Item name uniqueness

# %%
non_unique_list = []
non_unique_amount_list = []
for location_id in tqdm(location_ids):

    # Copy data to avoid overwriting
    data = restaurant_sales_data[location_id].copy()
    
    # Find near-duplicates and remove
    data.sort_values(['item_name', 'unit_price'], inplace=True)
    data['price_diff'] = data.groupby('item_name')['unit_price'].diff().abs()
    data = data[(data['price_diff'] >= 2) | (data['price_diff'].isna())] # Treat differences of less than 

    # Determine which items have multiple prices (with price differences greater than 2 cents) and filter to only those
    unique_price_counts = data.groupby('item_name')['unit_price'].nunique()
    items_with_multiple_prices = unique_price_counts[unique_price_counts > 1].index
    data = data[data['item_name'].isin(items_with_multiple_prices) & ~data['item_name'].str.contains('nan')]
    non_unique = data.drop_duplicates(subset=['item_name', 'unit_price'])

    # Add to lists
    non_unique_list.append(non_unique)
    non_unique_amount_list.append({'location_id' : location_id, 'unique_items' : non_unique['item_name'].nunique(), 'non_unique_amount' : non_unique.shape[0]})
    non_unique_amounts = pd.DataFrame(non_unique_amount_list)

# %%
# Write results to an Excel file
with pd.ExcelWriter('example_palate_data_issues/non_unique_items.xlsx') as writer:
    non_unique_amounts.to_excel(writer, sheet_name='non_unique_amounts')
    for location_id, df in tqdm(zip(location_ids, non_unique_list)):
        df.index = df.index.astype(str)
        df.to_excel(writer, sheet_name=location_id)

# %% [markdown]
# Merging

# %%
merged_sales_and_plant_based = {}
for location_id, df in tqdm(restaurant_sales_data.items()):
    merged = pd.merge(df.reset_index(), items_tagged[['item_name','is_plant_based']], left_on='item_name', right_on='item_name', how='left')
    merged.set_index('created_at', drop=True, inplace=True)
    merged_sales_and_plant_based[location_id] = merged

# %% [markdown]
# Identifying first plant-based

# %% [markdown]
# ### Sales Visuals

# %%
for location_id, df in merged_sales_and_plant_based.items():
    plt.bar(df['item_name'].value_counts().iloc[:20].index.str.slice(0,20), df['item_name'].value_counts().iloc[:20])
    plt.xticks(rotation=75)
    plt.title(location_id)
    plt.show()

# %%
for location_id, df in merged_sales_and_plant_based.items():
    df = df[df['is_plant_based'] == 'yes']
    plt.bar(df['item_name'].value_counts().iloc[:20].index.str.slice(0,20), df['item_name'].value_counts().iloc[:20])
    plt.xticks(rotation=75)
    plt.title(location_id)
    plt.show()

# %% [markdown]
# Fractional item quantities

# %%
fractional_quantity_restaurant_id = list(restaurant_sales_data.items())[5][0]
fractional_quantity_restaurant_df = restaurant_sales_data[fractional_quantity_restaurant_id]
fractional_quantity_examples = fractional_quantity_restaurant_df[~fractional_quantity_restaurant_df['item_quantity'].astype(str).str.contains(".0")]
fractional_quantity_examples.to_csv('example_palate_data_issues/fractional_quantities.csv')

# %%
# Step 2: Filter Data by Item Name
def filter_data_by_item(data, item_name):
    return data[data['item_name'] == item_name]

# Step 3: Plot Time Series
def plot_time_series(data, item_name):
    filtered_data = filter_data_by_item(data, item_name)
    filtered_data['timestamp'] = pd.to_datetime(filtered_data['timestamp'])
    plt.figure(figsize=(10, 6))
    plt.plot(filtered_data['timestamp'], filtered_data['sale_amount'])
    plt.title(f'Time Series of Sales for {item_name}')
    plt.xlabel('Timestamp')
    plt.ylabel('Sale Amount')
    plt.grid(True)
    plt.show()

# Load your data (replace 'your_sales_data.csv' with your actual file path)
sales_data = load_data('your_sales_data.csv')

# Step 4: User Input
item_to_plot = input("Enter the name of the item to plot: ")
plot_time_series(sales_data, item_to_plot)
