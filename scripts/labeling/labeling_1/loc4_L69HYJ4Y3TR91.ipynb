# %% [markdown]
# # L69HYJ4Y3TR91

# %% [markdown]
# Packages

# %%
# Imports
from foodcast.imports import *
os.chdir(find_project_root())
BASE_DIR, DATA_DIR_1, DATA_DIR_2, DATA_DIR_3, DATA_DIR_4, DATA_DIR_3_x = return_dir()
DATA_DIR_3_1, DATA_DIR_3_2, DATA_DIR_3_3, _, _, _, DATA_DIR_3_7, _, DATA_DIR_3_pre = DATA_DIR_3_x
DATA_DIR_3_pre_1, DATA_DIR_3_pre_2, DATA_DIR_3_pre_3 = DATA_DIR_3_pre

# Settings
notebook_settings() 

# Load Data
location_ids_by_coverage = load_loc_ids()
locations, before_after_details_true, items_tagged, customers = load_static()
loc_id = 'L69HYJ4Y3TR91'
df_uncleaned = load_one_res_2(loc_id)

# %%
# Item names to swap based on modications
modification_name_changes = [('Butter-Me-Crazy A√Ssai Bowl', 'Nutella|Yogurt' , 'Butter-Me-Crazy A√Ssai Bowl with Dairy'),
                             ('Let,Äôs Get Tropical A√Ssa√≠ Bowl', 'Honey|Bee Pollen' , 'Let‚Äôs Get Tropical A√Ssa√≠ Bowl with Honey/Bee Pollen'),
                             ('Aloha (Pineapple & Coconut)', 'Skim|Cream' , 'Aloha with Dairy'),
                             ('Mix & Match A√Ssa√≠ Bowl', 'No Pollen|No Honey' , 'Vegan Mix & Match A√Ssa√≠ Bowl'), 
                             ('Mix & Match A√Ssa√≠ Bowl', 'Nutella|Honey|Bee Pollen' , 'Mix & Match A√Ssa√≠ Bowl with Dairy/Honey'),
                             ('Mix & Match A√Ssa√≠ Bowl', '' , 'Vegan Mix & Match A√Ssa√≠ Bowl'),
                             ('Summer Strawberry Smoothie', '2%|Cream|Skim' , 'Summer Strawberry Smoothie with Dairy'),
                             ('Loco Paradise Smoothie', 'Skim|Whole Milk' , 'Loco Paradise Smoothie with Dairy'),
                             ('Berry-Licious A√Ssai Bowl', 'No Bee Pollen Or Honey' , 'Vegan Berry-Licious A√Ssai Bowl'), #should I count the ones with no honey but bee pollen as vegan?
                             ('Driving-Me-Hazy A√Ssa√≠ Bowl', 'No Nutella Honey' , 'Vegetarian Driving-Me-Hazy A√Ssa√≠ Bowl'),
                             ('Driving-Me-Hazy A√Ssa√≠ Bowl', 'No Nutella' , 'Vegan Driving-Me-Hazy A√Ssa√≠ Bowl'),
                             ('Driving-Me-Hazy A√Ssa√≠ Bowl', 'Nutella' , 'Vegetarian Driving-Me-Hazy A√Ssa√≠ Bowl'),
                             ('Driving-Me-Hazy A√Ssa√≠ Bowl', '' , 'Vegan Driving-Me-Hazy A√Ssa√≠ Bowl'),
                             ('Bagel', 'Bacon', 'Meat Bagel'),
                             ('Bagel', 'Peanut Butter', 'Vegan Bagel'),
                             ('Bagel', 'Cheese|Chese|Butter|Egg', 'Vegetarian Bagel'),
                             ('Bagel', '', 'Vegan Bagel'),
                             ('Keto Toasted Bagel', 'Cheese|Butter', 'Keto Toasted Bagel with Dairy'),
                             ('Bagel Joy Pizza', 'Pepperoni', 'Bagel Joy Pizza with Meat'),
                             ('Bagel Joy Pizza', 'Vegan', 'Vegan Bagel Joy Pizza'),
                             ('Avocado Toast', 'Bacon|Turkey', 'Meat Avocado Toast'),
                             ('Avocado Toast', 'No Egg', 'Vegan Avocado Toast'),
                             ('Gourmet Toasts', 'Avocado|Buttered', 'Gourmet Toast with Egg/Butter'),] 

#Yes Plant-based items to sort based on modifications:

#     Smart Fruit Smoothies TODO this has multiple other smoothies in it, should I split them somehow? How?
# DONE - Butter-Me-Crazy A√Ssai Bowl - all vegan except nutella, honey, bee pollen, yogurt
# DONE - Mix & Match A√Ssa√≠ Bowl' 
# DONE - 'Let‚Äôs Get Tropical A√Ssa√≠ Bowl',
# DONE - 'Aloha (Pineapple & Coconut)',
# DONE - 'Summer Strawberry',
# DONE - 'Summer Strawberry Smoothie',
# DONE - 'Loco Paradise (Strawberry & Banana)',
# DONE - 'Loco Paradise Smoothie',
# DONE -'Sr Signature Smoothie (Peanut Butter Banana + Espresso)'

#Unsure items to sort based on modifications:

#  DONE   'Toasted Bagels', 
#  DONE   'Bagel Joy Pizza',
#  DONE   'Gourmet Toasts', #not sure what to do with the avocado toast in this -- mark as veg, not vegan. Assume the default from the menu
#  DONE   'Bagels',  


# No, not plant based items to sort: **Going to count "no" as vegetarian, and sort out meat items**
    #TODO: do I need to do anything to make the no items default to veg? or should I just sort them manually?

    # 'Breakfast Sandwich',
    # 'Croissant',
    # 'Quiche',
    # 'Gourmet Grilled Cheese',
    # 'Grilled Cheese Toast',
    # DONE 'Keto Toasted Bagel',
    # DONE 'Avocado Toast',
    # DONE 'Bagel',
    # 'Melted Grilled Cheese',
    # 'Berry-Licious A√Ssai Bowl',
    # DONE 'Driving-Me-Hazy A√Ssa√≠ Bowl',
    # 'Chips',
    # 'Combo Chips'


vegan = ['Vegan Berry-Licious A√Ssai Bowl',
         'Vegan Driving-Me-Hazy A√Ssa√≠ Bowl',
         'Vegan Bagel',
         'Keto Toasted Bagel',
         'Vegan Bagel Joy Pizza',
         'Vegan Avocado Toast',
         'Vegan Mix & Match A√Ssa√≠ Bowl',
         'Gluten Free Chocolate Chip Cookie', #vegan if from The Difference Baker, which I am assuming bc other gf items
                                             # on menu are from there, and they have these at the bakery
         'Gluten Free Whoopie Pie',  #guessing these are vegan oatmeal or chocolate cream pies from The Difference Baker
         'Gluten Free Brownie', #Assuming this is from The Difference Baker
         'Gourmet Toasts'
         ]

vegetarian = ['Fresh Baked Banana Bread',
              'Gluten Free Cheesecake', 
              'Gluten Free Chocolate Coconut Macaroon',
              'Rice  Crispy Treats',
              'Gluten Free Coconut Macaroon',
              'Very Berry Parfait',
              'Butter-Me-Crazy A√Ssai Bowl with Dairy',
              'Let‚Äôs Get Tropical A√Ssa√≠ Bowl with Honey/Bee Pollen',
              'Aloha with Dairy',
              'Mix & Match A√Ssa√≠ Bowl with Dairy/Honey',
              'Summer Strawberry Smoothie with Dairy',
              'Loco Paradise Smoothie with Dairy',
              'Muffin',
              'Pop Tart',
              'Gluten Free Muffin',
              'Keto Muffins',
              'Danish',
              'Vegetarian Bagel',
              'Keto Toasted Bagel with Dairy',
              'Bagel Joy Pizza',
              'Vegetarian Driving-Me-Hazy A√Ssa√≠ Bowl',
              'Gourmet Toast with Egg/Butter',
              ]

meat = [
    'Bacon',
    'Blt',
    'Grilled Chicken Sandwich',
    'Turkey Cheddar Ciabatta Club',
    'Turkey Club Wrap',
    'Turkey Cheddar Sandwich',
    'Keto Pepperoni Rolls',
    'Keto Scones',
    'Meat Bagel',
    'Bagel Joy Pizza with Meat',
    'Meat Avocado Toast'
]

#sorted out miscategorized drinks and merch using Claude
non_alcoholic_drinks = [
    'Latte', 
    'Drip Coffee', 
    'Iced Latte', 
    'Cold Brew', 
    'Latte Non-Diary', 
    'Iced Latte (Non-Diary)', 
    'Cappuccino', 
    'Americano', 
    'Flat White', 
    'Chai Latte', 
    'Iced Chai Latte', 
    'Hot Cocoa', 
    'Hot Tea', 
    'Cortado', 
    'Iced Premium Matcha Latte', 
    'Nitro Cold Brew', 
    'Bottled Water', 
    'Iced Americano', 
    'Cafe Au Lait', 
    'Iced Tea', 
    'Breve', 
    'Signature Blend', 
    'Espresso', 
    'Red Eye', 
    'Premium Matcha Latte', 
    'Fresh Squeezed Oj', 
    'Sparkling Water', 
    'Horizon Chocolate Milk', 
    'Iced Breve', 
    'Cherry Blossom Latte', 
    'Cherrry Blossom Latte', 
    'Kids Steamer', 
    'Kids Latte', 
    'Ethiopia, The Proprietary Ii', 
    'Iced Cherry Blossom Latte', 
    'Hot Tea Latte', 
    'Nitro Brew Latte', 
    'Iced Kids Latte', 
    'Iced Matcha Elderflower Tea', 
    'Honduras, El Paraiso, The Decaf', 
    'Lemon Perfect Water', 
    'Espresso Tonic', 
    'Non Diary Milk', 
    'Blackberry Jasmine Iced Tea', 
    'Pineapple Lemonade', 
    'Bottle Water', 
    "Valentine'S Day Blend", 
    'Liquid Death Water', 
    'Catering Oj', 
    'Catering Lemonade', 
    'Hot Chai Tea', 
    'San Pellegrino', 
    'Tea', 
    'Freshly Squeezed Orange Juice',
    'Frappe',
    'Creme Frappe',
    "S'Mores Cr√®Me Frappe",
    'Matcha Cr√®Me Frappe',
    'Cherry Blossom Frappe',
    'Smores Frappe',
    'Cherry Blossom Cr√®Me Frappe',
    'Nicaragua, Mario\'S Miracle',
    'Guatemala, The Jade Reserve',
    'S\'Mores Frappe'
]

alcoholic_drinks = ['Bar Therapy']

merch = [
    'Coffee  Mug',
    'Coffee Clip Santa',
    'Coffee Clip-Mom',
    'Coffee Clip Quotes',
    'Holiday Gift Bag',
    'Artwork',
    'Spoons',
    'Hat- Sr',
    'Coaster- Mountain',
    'Solid Cologne',
    'Coaster Snowflake Individual',
    'Gift Card',
    'Egift Card',
    'Coffee Bag Clips',
    'Candle',
    'Lip Balm',
    'Valentine Cards',
    'Coaster Dead Head Mt',
    'Signature Sr Coffee Co. Hat',
    'Coffee Clip Dad',
    'Coffee Ornament Quote'
]

rare =[]

unknown = ['favor']

items_to_remove = ['Delivery'] #since this isn't an item?

# %%
# Extract the parts of the yaml to do the programmatic relabeling
df_relabeled = fully_relabel_and_consolidate(
    df                        = df_uncleaned,
    name_changes              = {},
    modification_name_changes = modification_name_changes,
    vegan_list                = vegan,
    vegetarian_list           = vegetarian,
    meat_list                 = meat,
    alcohol_list              = alcoholic_drinks,
    drinks_list               = non_alcoholic_drinks,
    merch                     = merch,
    unknown                   = unknown,
    remove_categories         = ["Merch", "Drink", "Alcohol"]
)

# # Are the labels uniquely specified?
# display(df_relabeled.groupby('item_name')['vegan'].unique()) 

df_relabeled.to_parquet(DATA_DIR_3_1 / (loc_id + '_sales_and_menu.parquet'))


# # There should be multiple labels for each item
# display(df_consolidated.groupby('item_name')['vegan'].unique()) 

df_relabeled.to_parquet(DATA_DIR_3_2 / (loc_id + '_sales_and_menu.parquet'))

plot_dish_time_series(df_relabeled, loc_id, before_after_details_true, legend=True, legend_min=7.75, legend_max=18.70, shift_adjustment=1/15)

# %%
promo_date = before_after_details_true.loc[loc_id, 'cross_over_date']
print(df_uncleaned.query('item_name.str.contains("Impossible") or item_modifications.str.contains("Impossible")')['item_quantity'].sum())
print(df_uncleaned.loc[promo_date:promo_date+pd.DateOffset(days=60)].query('item_name.str.contains("Impossible") or item_modifications.str.contains("Impossible")')['item_quantity'].sum())

plot_time_series_subset(
    df_uncleaned.query('item_modifications.str.contains("Impossible")'), 
    exposure=promo_date,
    freq='D',
    truncate=True)
plot_time_series_subset(
    df_uncleaned.query('item_modifications.str.contains("Impossible")'), 
    exposure=promo_date, 
    freq='D', 
    truncate=False)
plt.show()
