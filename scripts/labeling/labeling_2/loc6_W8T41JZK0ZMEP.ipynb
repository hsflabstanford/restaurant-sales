# %% [markdown]
# # W8T41JZK0ZMEP

# %% [markdown]
# Packages

# %%
# Imports
from foodcast.imports import *
os.chdir(find_project_root())
BASE_DIR, DATA_DIR_1, DATA_DIR_2, DATA_DIR_3, DATA_DIR_4, DATA_DIR_3_x = return_dir()
DATA_DIR_3_1, DATA_DIR_3_2, DATA_DIR_3_3, _, _, _, DATA_DIR_3_7, _ = DATA_DIR_3_x

# Settings
notebook_settings() 

# Load Data
location_ids_by_coverage = load_loc_ids()
locations, before_after_details_true, items_tagged, customers = load_static()
loc_id = 'W8T41JZK0ZMEP'
df_uncleaned = load_one_res_2(loc_id)
df_targeted = pd.read_parquet(DATA_DIR_3_7 / f'{loc_id}.parquet')

# %%
df_targeted.modifs('Banh Mi')

# %%
# Remapping was manual, but stored in a yaml now to stay organized
labeling_path = Path('scripts') / 'labeling'
remapping_path = labeling_path / 'remapping' / 'loc6_remappings.yaml'
with open(remapping_path, "r", encoding="utf-8") as f:
    remapping = yaml.load(f, Loader=yaml.FullLoader)

# Extract the parts of the yaml to do the programmatic relabeling
df_relabeled = fully_relabel_and_consolidate(
    df_uncleaned,
    remove=remapping.get("merch_list", []),
    modification_name_changes=remapping.get("modification_name_changes", []),
    vegan_list=remapping.get("vegan_list", []),
    vegetarian_list=remapping.get("vegetarian_list", []),
    meat_list=remapping.get("meat_list", []),
    drinks_list=remapping.get("non_alcoholic_drinks", []),
    alcohol_list=remapping.get("alcoholic_drinks", []),
    merch=remapping.get("merch_list", []),
    rare=remapping.get("rare_list", []),
    unknown=remapping.get("unknown_list", [])
)

df_relabeled.to_parquet(DATA_DIR_3_1 / (loc_id + '_sales_and_menu.parquet'))

df_consolidated = df_relabeled.pipe(rename_items, name_changes={})

plot_dish_time_series(df_consolidated, loc_id, before_after_details_true, top_n=30)

df_consolidated.to_parquet(DATA_DIR_3_2 / (loc_id + '_sales_and_menu.parquet'))

# %%
name_changes = {
"Curry": ["Sweet Potato Curry", "Tofu Curry", "Chickpea Curry", "Spinach Tofu Curry", "Thai Veggie Curry", "Butternut Squash Spinach Curry", "Chole Daal", "Punjabi Chickpea Curry"],
"Curried Cauliflower Soup": ["Curried Cauliflower"],
"Buffalo Tofu Chicken Wrap": ["Buffalo \"Tofu Chicken\" Wrap"],
"Soup": ["Hot Soup", "Veggie Lentil", "Vegan Hot Soup", "Roasted Red Pep Soup", "Red Lentil Soup"],
"Veggie Grilled Cheese": ["Cheese Melt Soup","Seasonal Soup - Grilled Cheese", "Grilled Cheese Tomato Soup", "Vegan Grilled Cheese Tomato Soup", "Soup Grilled Cheese", "Soup Grilled Sandwich", "Soup Grilled Vegan Cheese", "Soup And Cheese Melt", "Meltaway",
"Grilled Cheese Soup", "Veggie Melt Soup", "Veggie Melt Tomato Soup", "Veggie Melt Tomato Basil Soup", "Vegan Veggie Melt Tomato Soup", "Vegan Veggie Melt Tomato Basil Soup", "Hot Soup(VGf) With Grilled Turkey And Cheese (Vegan, Gf Option By Request)", "Tomato Soup And Grilled Turkey And Jack Cheese", "Soup Sandwich Special"],
}

name_changes.update({
"Acai Bowl": ["Acai Smoothie Bowl", "Collagen Acai Smoothie Bowl"],
"Almond Pear Cake": ["Walnut Pear Cake"],
"Apple Walnut Salad": ["Chicken Apple Walnut Salad"],
"April Showers Smoothie Bowl": ["April Showers Smoothie Bowl- Limited Offering!"],
"Asian Peanut Noodles": ["Thai Peanut Noodles", "Soba Noodles"],
"Autumn Salad": ["Autumn Salad Bowl", "Chicken Autumn Salad Bowl"],
"Avocado Toast": ["Avocado Toast - Gf Available", "Egg Avocado Toast", "Feta Toast", "Whipped Feta Toast", "Avo Toast Microgreens"],
"Banh Mi": ["Banh Mi-New For May!", "Banh Mi-Special For May !", "Bahn Mi"],
"Beet Burger": [],
"Beyond Burger": ["Cheese Beyond Burger"],
"Black Bean Burger": ["Black Bean Burger Chips"],
"Breakfast Bowl": ["Cheesy Breakfast Bowl W Egg", "Vegan Breakfast Bowl"],
"Breakfast Wrap": ["Breakfast Wrap- Gf Wrap Available", "Eggy Cheezy Breakfast Wrap", "Vegan Breakfast Wrap"],
"Buddha Bowl": ["Buddha Bowl-VeganGluten FreeDairy Free", "Buddha Salad Bowl", "Energy Buddha Bowl", "Enlightened Buddha Bowl", "Erie Buddha Bowl", "Power Buddha Bowl", "Chicken Buddha Bowl"],
})

name_changes.update({
"Cake Pops": ["Cake Pops- Gluten -Free","Cake Pops(2) Gluten -Free"],
"Candy Patty": ["Cashew Patty", "Coconut Patty", "Raisin Patty", "Cherry Cluster Patty", "Cherry Chocolate Cluster Patty", "Chocolate ClusterMeltawayPatty", "Cashew Chocolate Patty"],
"Carrot Cake": ["Vegan Carrot Cake", "Carrot Cake With Buttercream Frosting- VGt Whole Cake", "Carrot Cake, Slice", "Carrot Cake Slice", "Gf Carrot Cake Slice"],
"Carrot Cake Cupcake": ["Carrot Cake Cupcake - Gf", "Carrot Cake Cupcake - Gluten Free"],
"Carrot Cake Smoothie Bowl": [],
"Cauliflower Flatbread Pizza": ["Vegan Cheese Cauliflower Flatbread Pizza", "Chicken Cauliflower Flatbread Pizza"],
"Chia Pudding": ["Chia Pudding ( GfDf) Rotating Variations Of Fruits Superfoods", "Fresh Fruit Chia Pudding", "Chia Pudding Fruit Parfait", "Blueberry Almond Chia Pudding"],
"Chicken Curry Couscous On Greens": ["Chicken Curry Over Rice", "Curried Chicken Couscous"],
"Chicken Salad Over Greens": ["Chicken Salad Over Greens, Small Clamshell", "Chicken Salad With Baby Micro Medi Greens, Domed Salad Bowl", "Chicken Salads","Chicken Spinach Salad"],
"Chickpea Salad Over Greens": ["Chickpea Salad Over Greens (V)", "Chickpea Salad"],
"Chickpea Salad Wrap": ["Chickpea Salad Wrap -V Gf Wrap On Request", "V - Chickpea Salad Wrap", "V - Chickpea Salad Wrap Gf Wrap Available", "V - Chickpea Salad Wrap, Gf Wrap Available", "Chickpea Smash Wrap","V - Smash Wrap"],
"Chocolate Bar": ["Elements Chocolate Bar2Oz Bar", "Elements Chocolate Square (1Oz)", "Ginger Chocolate Bar", "Solid Chocolate Bar"],
"Chocolate Cake": ["Peanut Butter Chocolate Cake", "Chocolate Cake With Ganache And Raspberries, Gf"],
"Chocolate Chip Cookie Bar": ["Choc-Chip Cookie Bar, VGf","Chocolate Chip Cookie Bar, VGfNd"],
"Chocolate Covered Oreos":["Oreos, Chocolate Covered, Vegan"],
"Cilantro Lime Coleslaw": ["Cilantro Lime Coleslaw-Vegan Gf"],
"Cinnamon Roll": ["Dated Cinnamon Rolls", "Vegan Cinnamon Roll"],
"Cranberry Chicken Salad": ["Cranberry Chicken Salad- Hormone Antibiotic Free, Organic Chicken!"],
"Cranberry Chicken Wrap": ["Cranberry Chicken Salad Wrap-Organic, Hormone And Antibiotic Free Chicken"],
"Dragon Smoothie Bowl": ["Dragon Smoothie Bowl- May Seasonal"],
})

name_changes.update({
"Egg Bake": ["Egg Bakes", "Chicken Egg Bakes"],
"Energy Bars": ["V - Love Bites","Love Bites","Energy Bites", "Energy Bites, DfNdK", "Energy Bites - GfDairy-FreeKeto Friendly", "Blue Ocean Protein Balls"],
"Falafel": ["Falafel Pita", "Falafel Pita VGf", "Falafel Wrap VDf"],
"Farmer's Market Salad":["Farmer'S Market Salad", "Vegan Farmer'S Market Salad", "Chicken Farmer'S Market Salad"],
"Forbidden Wrap":["Forbidden Toasted Wrap"],
"Fudgy Brownie":["Fudgy Brownie VGf", "Fudgy Brownie - VGfDairy Free", "Fudgy Brownie, VGfNd", "V - Fudge Brownie", "Fudge Brownie", "Fudgy Brownie -", "Ganache Brownie: Gf", "Df Gf Brownie", "Black Bean Brownie"],
"Fudgy Espresso Brownie": ["Fudgy Espresso Brownie, VGfNd", "Fudgy Espresso Brownie, VGf"],
"Granola": ["Housemade Granola (Gf)", "Housemade Granola (VGf)", "Greek Yogurt, Fruit Granola"],
"Great Pumpkin Bowl": ["Great Pumpkin Bowl (Dairy)"],
"Green Goddess Salad Bowl": ["Green Goddess Salad", "Chicken Green Goddess Salad Bowl", "Goddess Salad", "Chicken Goddess Salad", "Egg Goddess Salad"],
"Green Goddess Smoothie Bowl":["Green Goddess Bowl"],
"Grilled Chicken Sandwich": ["Chicken And Side"],
"Honey By John": ["Honey-By John", "Honey-Raintree Farms", "Honey Comb In Honey", "Honey-Quart Bear (Mv Power)"],
"House Tomato Soup": ["Creamy Tomato Soup", "Tomato Basil Soup", "Tomato Soup", "Creamy Tomato"],
"Hippea Chips": ["Hippea Tortilla Chips", "Hippea, 4Oz Puffs Siracha", "Hippea, 10 Oz Puffs, Whtcheddar", "Hippea Cheddar Puff, 4Oz", "Hippea Tortilla Chip", "Hippea, 10 Oz Cheddarpuffs", "Hippea, 1.5Oz Puffs", "Hippea, 5Oz Srirachapuff"],
})

name_changes.update({
"Kale! Ceasar Salad": ["Regular Kale! Cesar Salad", "Caesar Salad WBlue Oyster Mushrooms-VGf"],
"Lemon Bar": ["Lemon Bar-Gf","Lemon Bar - Gf", "Lemon Bars"],
"Lion'S Mane Crab Cakes": [],
"Maple Syrup": ["Maple Syrup, Maple Brandy", "Maple Brandy Syrup"],
"Matcha Love Bowl": [],
"Matcha Pancakes":["Matcha Pancakes - VGfDf"],
"Mediterranean Falafel Salad": ["Mediterranean Falafel Bowl"],
"Meltaway": ["Peanut Butter Meltaway", "Peppermint Patty Meltaway", "Chocolate Peanut Butter Meltaway", "Lake Erie Chocolates"],
"Microgreens": ["Microgreens, Clamshell"],
"Mint To Be": ["Mint To Be Smoothie Bowl", "Mint Condition Bowl","Enchant Mint Bowl", "Enchant Mint"],
"Molasses Cookies": ["Ginger Molasses Cookies", "Ginger Molasses Cookies, VGfNd", "V - Ginger Molasses Cookies", "V - Ginger Molasses Cookies (1)", "Molasses Cookie VGf"],
"Muffins": ["Cranberry Orange Muffin", "Morning Glory Muffin, V", "Banana Chocolate Chip Muffin", "Carrot Cake Muffin", "V-Cranberry Orange Muffin", "Banana Nut Muffin", "V-Protein Packed Banana Nut Muffin"],
})

name_changes.update({
"Oatmeal": ["Oatmeal-Gluten Free, Organic Oats!", "Oatmeal: Gluten-Free, Organic Oats"],
"Pb & J Bowl": ["Pb J", "Pb J Bowl", "Collagen Pb J Bowl", "Collagen Pb J"],
"Pb Choc Cupcake": ["V-Pb Choc Cupcake", "V - Pb Choc Cupcake","Pb Chocolate Cupcake VGf"], # Vegan
"Peanut Butter Scotchy Bar": ["Peanut Butter Scotchy Bar, GfNdK", "Pb Scotchy, VGf"],
"Peppermint Brownie": ["Peppermint Frosted Brownie (VGfDf)", "Peppermint Fudge Brownie"],
"Peppermint Mocha Bowl": ["Peppermint Mocha Smoothie Bowl"],
"Pineapple Coconut Rice Bowl": ["Pineapple Coconut Rice Bowl (VGf)", "Pineapple Coconut Rice Bowl, VGf"],
"Pumpkin Muffin": ["VGf Pumpkin Muffin", "Gf/V Pumpkin Muffin", "Pumpkin Muffin - VGf","Pumpkin Muffin V"], # Vegan
"Pumpkin Waffles":["V Gf Pumpkin Waffles","Pumpkin Waffles V"], # Vegan
"Quesadilla": ["Toasted Quesadilla", "Sofritas Quesadilla", "Southwest Quesadilla", "Hallow'S Eve Quesadilla", "Vegan Toasted Quesadilla", "ChickenSour Cream Toasted Quesadilla", "Vegan Cheddar Sofritas Quesadilla", "Sw Quesadilla"],
"Quiche": ["Quiche (Artichoke Red Pepper) W Side Salad", "Frittata", "Frittata And Side Salad", "Frittata Side Salad", "Cheddar Broccoli Quiche Side Salad (Gf)"],
"Raspberry Bar": ["Raspberry Cheescake Bar", "Raspberry Lemon No-Bake Bar", "V - Raw Raspberry \"Cheesecake\" Bar", "V - Raspberry Lemon No Bake", "Raspberry Lemon No-Bake Bar Vegan"], # Unclear
"Reuben-Vegan Or Regular": ["Reuben-Vegan(Tofu) Or Rachel(Turkey)", "Turkey Reuben-Vegan(Tofu) Or Rachel(Turkey)", "Reuben And Fries", "Vegan Reuben And Fries"],
"Rice Krispie Bar": ["Rice KrispieScotchy Bar", "Rice Krispie Treat", "Crisped Rice Bar"],
})

name_changes.update({
"Smash Burger": ["Smash Burger Chips", "Chickpea Burger"],
"Soup": ["Hot Soup", "Veggie Lentil", "Vegan Hot Soup", "Red Lentil Soup", "Roasted Red Pep Soup"],
"Specialty Smoothie Bowl": ["Tropical Nice Cream Bowl", "Redwhite Berry Bowl", "Christmas Smoothie Bowl", "Christmas Bowl", "Goldblum Bowl", "Serenity Now", "Pb Smoothie Bowl"],
"Spiced Yam Cake- Wedge": ["Spiced Yam Cake Wedge, GfNd", "Spiced Yam Cake Wedge, GfDf", "Yam Pecan Cake Gf", "Pecan And Yam Bundt Cake"],
"Sweet Potato Fries": ["Side Of Fries", "Loaded Sweet Potato Fries"],
"Spinach Lental Rice Bow":["Spinach Lentil Rice Bowl","Lentil Highland Rice Bowl"],
"Tacos":["Jackfruit Tacos"],
"Tex Mex Burrito Bowl": ["Texmex Bowl"],
"Vegan Breakfast Sandwich": ["Vegan Breakfast Sandwich-The Jj Sammy", "Veg Breakfast Sandwich"],
"Vegan Cheesecake": ["V - \"Cheese\"Cake", "Cheesecake V Gf", "Caramel \"Cheese\"Cake", "Gingersnap Cheesecake VGf", "Carmel Cheesecake With Slated Caramel Sauce"],
"Vegan Cookie Bar": ["V - Cookie Bar", "Co-Op Vegan Cookie"], # Vegan
"Vegan Lemon Bar": ["V- Lemon Bar", "Lemon Bars, V, Gf","V-Lemon Bar"], # Vegan
"Zucchini Muffin": ["Zucchini Blue Muffin", "Zucchini Berry Muffin", "Zucchini Blue Muffin Gf", "Zucchini Blue Muffin GfNd", "Zucchini Blueberry Muffin"],
"Vegan Shepards Pie": ["Shepard'S Pie Side Salad"],
})


modification_name_changes = [
('Desserts Baked Goods', 'Energy Bites', 'Energy Bars'),
('Desserts Baked Goods', 'Vegan Cookie Bar', 'Vegan Cookie Bar'),# Vegan
('Desserts Baked Goods', 'Zucchini Muffin', 'Zucchini Muffin'),
('Desserts Baked Goods', 'Vegan Cupcake', 'Vegan Cupcake'),# Vegan
('Desserts Baked Goods', 'Chocolate Chip Brownie', 'Chocolate Chip Brownie'),
('Desserts Baked Goods', 'V Gf Brownie', 'Fudge Brownie'), # Vegan
('Desserts Baked Goods', 'Lemon Bar', 'Lemon Bar'),
('Desserts Baked Goods', 'Walnut Brownie', 'Walnut Brownie'),
('Desserts Baked Goods', 'Muffins', 'Muffins'),
('Desserts Baked Goods', 'Gf Carrot Cupcake', 'Carrot Cake Cupcake'),
('Desserts Baked Goods', 'Molasses Cookies', 'Molasses Cookies'),
('Desserts Baked Goods', 'Vegan Cheesecake', 'Vegan Cheesecake'),# Vegan
('Desserts Baked Goods', 'Vegan Muffin', 'Vegan Muffin'),# Vegan
('Desserts Baked Goods', 'Almond Pear Cake', 'Almond Pear Cake'),
('Desserts Baked Goods', 'Zucchini Muffin, Gf', 'Zucchini Muffin'),
('Desserts Baked Goods', 'Vegan Peanut Butter Fudge', 'Vegan Peanut Butter Fudge'),# Vegan
('Desserts Baked Goods', 'Peppermint Fudge Brownie', 'Peppermint Fudge Brownie'),
('Desserts Baked Goods', 'Energy Bites, Gf', 'Energy Bars'),
('Desserts Baked Goods', 'Chocolate Chip Cookie Bar, V Gf', 'Chocolate Chip Cookie Bar'), # Vegan
('Desserts Baked Goods', 'Rice Krispie Treat', 'Rice Krispie Treat'),
('Desserts Baked Goods', 'Raspberry Lemon No-Bake Bar, Vegan', 'Raspberry Lemon No-Bake Bar Vegan'),# Vegan
('Desserts Baked Goods', 'Vegan Gf Cake Slice', 'Vegan Gf Cake Slice'),# Vegan
('Desserts Baked Goods', 'Carrot Cake Muffin', 'Carrot Cake Muffin'),
('Desserts Baked Goods', 'Df Gf Brownie', 'Df Gf Brownie'),
('Desserts Baked Goods', 'Jumbo Walnut Brownie', 'Jumbo Walnut Brownie'),
('Desserts Baked Goods', 'Cookie Bar Sandwich', 'Cookie Bar Sandwich'),
('Desserts Baked Goods', 'Carrot Cake Cupcake, Gf', 'Carrot Cake Cupcake'),
('Desserts Baked Goods', 'Pb Chocolate Cake', 'Pb Chocolate Cake'),
('Desserts Baked Goods', 'Rice Krispie Treat, V Gf', 'Rice Krispie Treat V Gf'), # Vegan
('Desserts Baked Goods', '"Cheese"Cake, V Gf', 'Cheesecake V Gf'), # Vegan
('Desserts Baked Goods', 'Love Bites', 'Love Bites'),
('Desserts Baked Goods', 'Molasses Cookies, V Gf', 'Molasses Cookies V Gf'), # Vegan
('Desserts Baked Goods', 'Chocolate Chip Brownie, Gf', 'Chocolate Chip Brownie'),
('Desserts Baked Goods', 'Vegan Berry Coconut Bars', 'Vegan Berry Coconut Bars'),# Vegan
('Desserts Baked Goods', 'Co-Op Vegan Cookie', 'Co-Op Vegan Cookie'),# Vegan
('Desserts Baked Goods', 'Cake Bite', 'Cake Bite'),
('Desserts Baked Goods', 'Fudgy Brownie, V Gf', 'Fudgy Brownie'), # Vegan
('Desserts Baked Goods', 'Co-Op Macaroon', 'Co-Op Macaroon'),
('Desserts Baked Goods', 'Yam Pecan Cake Gf', 'Yam Pecan Cake Gf'),
('Desserts Baked Goods', 'Walnut Brownie, Gf', 'Walnut Brownie Gf'),
('Desserts Baked Goods', 'Scone', 'Scone'),
('Desserts Baked Goods', 'Gf Carrot Cake Slice', 'Gf Carrot Cake Slice'),
('Desserts Baked Goods', 'Vegan Cookie Bar Lemon Bar', 'Vegan Cookie Bar Lemon Bar'),# Vegan
('Desserts Baked Goods', 'Carrot Cake Slice', 'Carrot Cake Slice'),
('Desserts Baked Goods', 'Walnut Pear Cake', 'Walnut Pear Cake'),
('Salads','Chickpea Salad On Greens','Chickpea Salad Over Greens'),
('Salads','Chickpea Burger Over Greens','Smash Burger'),
('Soup','','Soup'),
('Entree','Chickpea Burger','Smash Burger'),
('Entree', 'Chicken And Side', "Grilled Chicken Sandwich"),
('Entree','Vegan Meal', 'Vegan Chicken Wrap'),
("Gluten Free Desserts Baked Goods",'Zucchini Muffin, Gf','Zucchini Muffin'),
("Gluten Free Desserts Baked Goods",'Chocolate Chip Cookie Bar, V Gf','Chocolate Chip Cookie Bar'), # Vegan
("Gluten Free Desserts Baked Goods",'Scotchy Bar - Healthy Rice Crispy, V GfDairy-FreeKeto Friendly','Peanut Butter Scotchy Bar'), # Vegan
("Gluten Free Desserts Baked Goods",'Carrot Cake Cupcake, Gf','Carrot Cake Cupcake'),
("Gluten Free Desserts Baked Goods",'Raspberry Lemon No-Bake Bar, Vegan','Raspberry Lemon No-Bake Bar'),
("Gluten Free Desserts Baked Goods",'Energy Bites, Gf','Energy Bars'),
("Gluten Free Desserts Baked Goods",'"Cheese"Cake, V Gf','Vegan Cheesecake'),
]

# %%
filtered1 = (
    df_targeted
    #.query('~item_name.isin(@items_less_than_2_dollars)')
    .pipe(lambda df: rename_items(df, name_changes))
    .pipe(lambda df: rename_items_by_modifications(df, modification_name_changes))
    )

# %%
# filtered2 = (
#     filtered1
#     #.query('~item_name.isin(@items_less_than_2_dollars)')
#     .pipe(lambda df: rename_items(df, name_changes))
#     .pipe(lambda df: rename_items_by_modifications(df, modification_name_changes))
#     )

# %%
items_less_than_2_dollars = (
    filtered1
    .groupby('item_name')
    ['unit_price']
    .max()
    .to_frame(name='max_unit_price')
    .query('max_unit_price < 200.0')
    .reset_index()
    #.query('~item_name.isin(["Pumpkin Bread","Muffin Marionberry Cobbler","Muffin Chocolate"])')
    .item_name
    .tolist()
    )

missed_merch = ["Gummy Dinosaurs, Gf",
"Antioxidant Trail Mix",
    "Badda Bean",
    "Beesknees, Cinnamon Maple Syrup",
    "Cbd Jellybeans","Jelly Beans","Taffy","Nuts.Com Snack Pack",
    "Special Cake Order","Side Sauces", # Component, not a dish
    "Snakes On A Plane","",
    "Snack Pack",
    "Endangered Chocolate Bar",
    "Honey",
    "Happy Mug Coffee 12Oz Bag",
    "Spudlove Potato Chips",
    "Enlightened Beans",
    "Gin Bao",
    "Gum, Simply Gum",
    "Gummy Sharks, Gf",
    "Luke'S Cheese Puffs, 4Oz",
    "Elderberry Gummies",
    "Potato Chips, Dirty Potato Company",
    "Maple Syrup",
    "Elderberry Syrup 8Oz",
    "Oui Yogurt",
    "Hummus","Hummus Veggie Cup","Pretzel Or Carrots And Hummus",
    "Keto Bar","Hard Boiled Eggs, 2, Packaged","Chocolate Bar","Hippea Chips"]

missed_drinks = ['Salaminjaro',"Custom","Abdullah", # Alias for Aphrodite shot
    "Aphrodite",
    "Boost",
    "Calm",
    "Celery", # Interpreted as a pressed juice based on its modifications
    "Flu Shot",
    "Ginger Shot",
    "Ginger Snap", # Defined as a cold-pressed juice in your new menu
    "Glow",
    "Good Gut",
    "High Voltage",
    "Immunity Shot",
    "Magic Mind | Mental Performance Shot",
    "Pear Ginger", # Assumed juice/drink
    "Pot O' Gold", # Assumed juice/drink
    "Revive", # On official menu list, but not in sales data
    "Spicy Beet", # Assumed juice/drink
    "The Roots", # Assumed juice/drink
    "Vitali-D",
    "Zinger",
    "1 Day Nutrition Reboot", # Juice-based cleanse
    "3 Day Nutrition Reboot", # Juice-based cleanse
]
cookies = []
take_and_go = []

items_less_than_10_sales = filtered1.item_name.value_counts().to_frame('c').query('c < 10').index.tolist()

filtered3 = (
    filtered1
    .query('~item_name.isin(@items_less_than_2_dollars)')
    .query('~item_name.isin(@missed_merch)')
    .query('~item_name.isin(@missed_drinks)')
    .query('~item_name.isin(@items_less_than_10_sales)')
    #.query('~item_name.isin(@take_and_go)')
    #.query('~item_name.isin(@cookies)')
    .pipe(lambda df: rename_items(df, name_changes))
    .pipe(lambda df: rename_items_by_modifications(df, modification_name_changes))
    .query('~item_name.isin(@items_less_than_2_dollars)')
    .query('~item_name.isin(@missed_merch)')
    .query('~item_name.isin(@missed_drinks)')
    .query('~item_name.isin(@items_less_than_10_sales)')
    )


print(
    filtered3
    .groupby('item_name')
    ['item_modifications']
    .apply(lambda s: s.value_counts().index.str.slice(0,20).tolist()[0:3])
    .loc[filtered3.item_name.value_counts().index.tolist()]
    .to_frame()
    .join(filtered3.item_name.value_counts())
    .reset_index()
    .set_index('count')
    [['item_name','item_modifications']]
    #.iloc[10:,:]
    .to_string()
)

plot_dish_time_series(filtered3.set_index('created_at'), loc_id, before_after_details_true, top_n=70)

# %%
s = pd.Series([np.nan, 1, np.nan, np.nan, np.nan, 1, np.nan, np.nan, 1, np.nan])
print(s.tolist())
print(strict_bridge_fill(s.to_frame(), limit=2).squeeze().tolist())
print(strict_bridge_fill(s.to_frame(), limit=3).squeeze().tolist())

presence_dict = {}
for item, group in filtered3.groupby("item_name"):
    presence_dict[item] = infer_active_days(group["created_at"], max_gap_days=120)
presence_df = pd.concat(presence_dict, axis=1).fillna(False)

presence_weekly = presence_df.resample('W').max().fillna(False).astype(bool).to_period('W')
dish_order = list(filtered3.item_name.value_counts().index)
plot_boolean_time_series(presence_weekly, loc_id, before_after_details_true, dish_order, [])
plot_dish_time_series(filtered3.set_index('created_at'), loc_id, before_after_details_true, top_n=70)

presence_daily = strict_bridge_fill(presence_df, limit=7).resample('D').max()
#presence_daily = (presence_weekly.astype(float).replace(0.0, np.nan)[vegetarian_dishes].resample('D').interpolate(limit=6).fillna(0).astype(int).sum(axis=1).plot())
menu = pd.read_csv(Path("scripts") / "labeling" / "dish_labels" / (loc_id + ".csv"))

vegan_dishes = menu.loc[menu["vegan"], "item_name"]
vegetarian_dishes = menu.loc[menu["vegetarian"], "item_name"]
mpbamod_dishes = menu.loc[menu["mpbamod"], "item_name"]

vegan_dishes_count = presence_daily[vegan_dishes].sum(axis=1)
vegetarian_dishes_count = presence_daily[vegetarian_dishes].sum(axis=1)
promo_date = before_after_details_true.loc[loc_id, 'cross_over_date']
#indicator = pd.to_datetime(promo_date) < presence_daily.index
mpbamod_dishes_count = presence_daily[mpbamod_dishes].sum(axis=1) #* indicator
menu_counts = pd.concat([vegan_dishes_count, vegetarian_dishes_count, mpbamod_dishes_count], axis=1).set_axis(['vegan_dishes_count', 'vegetarian_dishes_count', 'mpbamod_dishes_count'], axis=1)
menu_counts.plot()
menu_counts.to_csv(Path("scripts") / "labeling" / "dish_counts" / (loc_id + ".csv"))

# %%
promo_date = before_after_details_true.loc[loc_id, 'cross_over_date']
print(df_uncleaned.query('item_name.str.contains("Vegan")')['item_quantity'].sum())
print(df_uncleaned.loc[promo_date:promo_date+pd.DateOffset(days=60)].query('item_name.str.contains("Vegan")')['item_quantity'].sum())

# Your original time series plots
plot_time_series_subset(
    df_uncleaned.query('item_name.str.contains("Vegan Breakfast Sandwich")'), 
    exposure=promo_date,
    freq='D', 
    truncate=False)
plot_time_series_subset(
    df_uncleaned.query('item_name.str.contains("Vegan Breakfast Sandwich")'), 
    exposure=promo_date,
    freq='D',
    truncate=True)
plt.show()

# Parse promo strings / lists
promo_name = before_after_details_true.loc[loc_id,'promo_name']
if isinstance(promo_name, str) and promo_name.startswith('['):
    import ast
    promo_list = ast.literal_eval(promo_name)
    vegan_str, bacon_str = promo_list[0], promo_list[1]
else:
    vegan_str, bacon_str = "Vegan Breakfast Sandwich", "Vegan Cheese"

# Define filters
filters = {
    'Vegan Breakfast Sandwich': lambda df: df['item_name'].str.contains("Vegan Breakfast Sandwich", na=False),
    'Vegan Cheese': lambda df: df['item_modifications'].str.contains("Vegan Cheese", na=False),
    'Unchicken': lambda df: df['item_modifications'].str.contains("Unchicken|Un'chicken", na=False),
    'Vegan Cupcake': lambda df: df['item_modifications'].str.contains("Vegan Cupcake", na=False),
    'Vegan Sausage': lambda df: df['item_modifications'].str.contains("Vegan Sausage", na=False),
    'Vegan Cheese (Alt)': lambda df: df['item_modifications'].str.contains("Vegan Cheese|Vegan Cheddar", na=False)
}

# Plot results
plt.figure(figsize=(12, 6))
for label, filter_func in filters.items():
    data = df_uncleaned.loc[filter_func(df_uncleaned)]
    plt.plot(data.resample('W')['item_quantity'].sum(), label=label)
plt.axvline(x=promo_date, color='red', linestyle='--', label='Promo Date')
plt.title("Plant-Based Analog")
plt.legend()
plt.xticks(rotation=50)
plt.show()

plot_dish_time_series(
    df_consolidated
    .dropna(subset='item_modifications')
    .query('item_name.str.contains("Desserts") and item_modifications.str.contains("Vegan")')
    .assign(item_name = lambda df: df['item_modifications']),
    loc_id,
    before_after_details_true,
    top_n=30)

plot_time_series(
    df_uncleaned, 
    exposure = promo_date,
    freq='W', 
    truncate=False)
plot_time_series(
    df_uncleaned.dropna(subset='item_modifications').query('item_name.str.contains("V - Smash Wrap")'), 
    exposure = promo_date,
    freq='W', 
    truncate=False)
plt.show()

# %%
#df_uncleaned.dropna(subset='item_modifications').query('item_modifications.str.contains("Vegan Cupcake")').index[0]
#df_uncleaned.loc[:pd.Timestamp('2020-04-27 13:28:58-0400', tz='America/New_York')]

print(df_consolidated.dropna(subset='item_modifications').query('item_modifications.str.contains("Vegan Cupcake")').index[0])
print(df_consolidated.dropna(subset='item_modifications').query('item_modifications.str.contains("Vegan Gf Cake Slice")').index[0])
print(df_consolidated.dropna(subset='item_modifications').query('item_modifications.str.contains("Vegan Cheesecake")').index[3])
print(df_consolidated.dropna(subset='item_modifications').query('item_modifications.str.contains("Bar, Vegan")').index[0])
print(df_consolidated.dropna(subset='item_modifications').query('item_name.str.contains("Vegan Breakfast Sandwich")').index[0])

"""vegan cupcake 2020-04-27
vegan cheesecake 2020-02-17
vegan gf cake slice 2020-07-13
vegan raspberry lemon no bake 2021-02-05"""

start_offset = df_uncleaned.index[0] + pd.DateOffset(days=30)
mask = df_uncleaned.item_modifications.value_counts().gt(10) & df_uncleaned.item_modifications.value_counts().index.str.contains("V:|VG|V/|V\)|V\]|V |V\s*$|Vegan|Plant-based|Plant based", case=False, regex=True)
df_uncleaned.reset_index().groupby('item_modifications')['created_at'].first().loc[mask].to_frame(name = 'first').query('@start_offset < first').sort_values('first').join(df_uncleaned.item_modifications.value_counts(), how='left')

df_uncleaned.query('item_name.str.contains("Cheesecake")')[['item_name','item_modifications']].value_counts()
start_offset = df_uncleaned.index[0] + pd.DateOffset(days=30)
mask = df_uncleaned.item_name.value_counts().gt(10) & df_uncleaned.item_name.value_counts().index.str.contains("V:|VG|V/|V\)|V\]|V |V\s*$|Vegan|Plant-based|Plant based", case=False, regex=True)
df_uncleaned.reset_index().groupby('item_name')['created_at'].first().loc[mask].to_frame(name = 'first').query('@start_offset < first').sort_values('first').join(df_uncleaned.item_name.value_counts(), how='left')

df_uncleaned.assign(item_modifications = lambda df: df.item_modifications.fillna('')).query('item_name.str.contains("Raspberry")')#[['item_name','item_modifications']].value_counts()

# clean_df.query('item_name.str.contains("Smash")')[['item_modifications']].value_counts()
# clean_df.query('item_name == "Wraps"')[['item_name','item_modifications','is_plant_based']].value_counts()
